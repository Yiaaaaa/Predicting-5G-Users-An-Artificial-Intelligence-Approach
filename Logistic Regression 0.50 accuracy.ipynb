# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd

#Import data
data = pd.read_csv('D:/train.csv')
data
# Out:
#             id  cat_0  cat_1  cat_2  cat_3  cat_4  cat_5  cat_6  cat_7  cat_8  \
# 0            0      2    103      9      4      3      1      3      4      4
# 1            1      0    177      6      2      2      1      2      4      4
# 2            2      7     70      7      4      5      0      3      4      4
# 3            3     11    166      7      2      3      1      1      1      2
# 4            4      0    178     10      4      3      0      4      4      4
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 799995  799995     17    224      7      4      5      1      2      4      4
# 799996  799996      9     62      8      4      4      0      2      4      4
# 799997  799997     29    111      4      1      5      1      1      0      4
# 799998  799998     18    325      7      4      3      1      4      4      4
# 799999  799999      4    124      1      4      2      1      9      4      4
#
# ...

# %%
#Remove the first column 'id' and the last column 'target' from x_data
y_data = data['target'].values[0:]
x1 = data.drop('target', axis=1)
x_data=x1.drop('id',axis=1).values[0:]
print(x_data)
print(y_data)
# Out:
# [[2.00000000e+00 1.03000000e+02 9.00000000e+00 ... 0.00000000e+00
#   8.97579193e-02 1.29425972e-04]
#  [0.00000000e+00 1.77000000e+02 6.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 3.11791962e-04]
#  [7.00000000e+00 7.00000000e+01 7.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 1.64438156e-04]
#  ...
#  [2.90000000e+01 1.11000000e+02 4.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 4.94371678e-04]
#  [1.80000000e+01 3.25000000e+02 7.00000000e+00 ... 1.07765198e-04
#   5.89824884e+03 1.42456907e-04]
#  [4.00000000e+00 1.24000000e+02 1.00000000e+00 ... 9.85495739e-03
#   3.12994017e+03 2.38002955e-04]]
# [0. 0. 0. ... 0. 0. 0.]

# %%
from sklearn import model_selection
x_train, x_test, y_train, y_test = model_selection.train_test_split(x_data, y_data, test_size=0.2)

# %%
#Create a logistic regression model object and train it using the fit method
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#After training the samples, use the trained model to make predictions on the test set
y_pred = classifier.predict(x_test)
print("预测结果为：",y_pred)
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
# 预测结果为： [0. 0. 0. ... 0. 0. 0.]
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99    157915
#          1.0       0.08      0.00      0.00      2085
#
#     accuracy                           0.99    160000
#    macro avg       0.53      0.50      0.50    160000
# weighted avg       0.98      0.99      0.98    160000

# %%
#Using the AUC standard to score the model's predicted results
from sklearn.metrics import roc_auc_score
x_pred=x_test
Y_pred=classifier.predict(x_pred)
y_true=y_test
roc_auc_score(y_true,y_pred)
# Out:
# 0.5004036260590363
