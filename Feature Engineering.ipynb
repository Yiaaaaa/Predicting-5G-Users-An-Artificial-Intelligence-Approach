# %%
# Importing the numpy and pandas libraries for data processing.
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn import preprocessing
# %matplotlib inline

# %%
# Importing the data.
df = pd.read_csv('train.csv')
df.shape
# Out:
# (800000, 60)

# %%
# Performing data normalization.
target=df.target
nouse=['id','target']
df=df.drop(nouse,axis=1)
df=pd.concat([df,target],axis=1)
df.head()
# Out:
#    cat_0  cat_1  cat_2  cat_3  cat_4  cat_5  cat_6  cat_7  cat_8  cat_9  ...  \
# 0      2    103      9      4      3      1      3      4      4      4  ...
# 1      0    177      6      2      2      1      2      4      4      4  ...
# 2      7     70      7      4      5      0      3      4      4      4  ...
# 3     11    166      7      2      3      1      1      1      2      4  ...
# 4      0    178     10      4      3      0      4      4      4      4  ...
#
#       num_29  num_30    num_31  num_32  num_33  num_34  num_35       num_36  \
# 0   2.000000     3.0  0.000000     0.0     0.0     0.0     0.0     0.089758
# 1   0.968742     0.0  0.000000     0.0     0.0     0.0     0.0     0.000000
# 2   0.000000     0.0  0.000000     0.0     0.0     0.0     0.0     0.000000
# 3   0.021729     0.0  0.021729     0.0     0.0     0.0     0.0     0.000081
# 4  30.000000    30.0  0.000000     0.0     0.0     0.0     0.0  6127.621124
#
#      num_37  target
# 0  0.000129     0.0
# ...

# %%
import matplotlib.gridspec as gridspec
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')
# Select only the anonymized features
goal = df.iloc[:, :]

length = len(goal.columns)
v_feat = goal.columns

plt.figure(figsize=(16, length*4))
gs = gridspec.GridSpec(length, 1)

for i, cn in enumerate(df[v_feat]):
    ax = plt.subplot(gs[i])
    sns.histplot(data=df, x=cn, hue="target", bins=50 if df["target"].nunique() > 2 else 100, kde=True)
    ax.set_xlabel('')
    ax.set_title('Histogram of feature: ' + str(cn))

plt.tight_layout()
plt.show()

# Describe the relationship between each feature and the target.
